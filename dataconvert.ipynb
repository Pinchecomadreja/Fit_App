# %%
import pandas as pd
import matplotlib as mp

data = pd.read_csv("data.csv")

# %%
data
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
#data.head()
#data.head(2) toma desde el principio(rows)
#data.tail(2) toma desde el final(rows)
data.columns[2]
# Out:
# 'Weight (kg)'

# %%
data["Weight (kg)"]
data["Height (m)"]
# Out:
# 0      1.71
# 1      1.53
# 2      1.66
# 3      1.70
# 4      1.79
#        ...
# 968    1.74
# 969    1.61
# 970    1.76
# 971    1.83
# 972    1.63
# Name: Height (m), Length: 973, dtype: float64

# %% [markdown]
# <H4>BUSCA ROW ESPECIFICA</H4>

# %%
data.loc[5:10]
# Out:
#     Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 5    56  Female         58.0        1.68      168      156           74
# 6    36    Male         70.3        1.72      174      169           73
# 7    40  Female         69.7        1.51      189      141           64
# 8    28    Male        121.7        1.94      185      127           52
# 9    28    Male        101.8        1.84      169      136           64
# 10   41    Male        120.8        1.67      188      146           54
#
#     Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 5                       1.59           1116.0         HIIT            15.5
# 6                       1.49           1385.0       Cardio            21.3
# 7                       1.27            895.0       Cardio            30.6
# 8                       1.03            719.0     Strength            28.9
# 9                       1.08            808.0       Cardio            29.7
# ...

# %% [markdown]
# <h4>Usa label to loc</h4>

# %%
pesoyaltura=data.loc[:4,["Weight (kg)","Height (m)"]]
pesoyaltura
# Out:
#    Weight (kg)  Height (m)
# 0         88.3        1.71
# 1         74.9        1.53
# 2         68.1        1.66
# 3         53.2        1.70
# 4         46.1        1.79

# %% [markdown]
# <h4>Usa index to loc</h4>

# %%
#genero = data.iloc[:10,1]
#peso = data.iloc[:10,2]
#altura = data.iloc[:10,3]
#data.iloc[:5,[1,2]]
data.iloc[:5,[0,1,2,3]]
# Out:
#    Age  Gender  Weight (kg)  Height (m)
# 0   56    Male         88.3        1.71
# 1   46  Female         74.9        1.53
# 2   32  Female         68.1        1.66
# 3   25    Male         53.2        1.70
# 4   38    Male         46.1        1.79

# %%
data.sort_values("Weight (kg)",ascending=False)
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 593   55    Male        129.9        1.73      187      155           60
# 122   56    Male        129.5        1.95      160      129           66
# 854   48    Male        129.2        1.61      193      167           62
# 96    56    Male        129.0        1.78      194      126           64
# 283   20    Male        128.4        1.92      167      145           57
# ..   ...     ...          ...         ...      ...      ...          ...
# 238   24  Female         40.4        1.64      168      168           55
# 156   56  Female         40.4        1.80      196      165           72
# 764   22  Female         40.3        1.56      192      121           57
# 705   47  Female         40.0        1.76      173      132           63
# 194   49  Female         40.0        1.65      188      148           74
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
data.sort_values(["Age","Height (m)"],ascending=[0,1])#[0,1]-> [x,y] x=num order y=alpha order
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 56    59  Female         65.5        1.52      161      162           61
# 95    59  Female         54.6        1.57      164      169           64
# 344   59    Male         89.4        1.62      198      125           59
# 385   59  Female         42.1        1.65      172      132           59
# 943   59    Male         85.5        1.67      190      144           71
# ..   ...     ...          ...         ...      ...      ...          ...
# 610   18    Male         82.3        1.84      190      148           66
# 459   18    Male         62.0        1.85      161      121           53
# 113   18    Male         87.6        1.93      161      139           72
# 587   18    Male         83.2        1.96      183      150           67
# 884   18    Male        114.5        1.97      192      128           60
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %% [markdown]
# # Filtrar data

# %%
#podemos buscar con loc una columna en particular con un filtro 
#base[base[row especifica]filtro][[base acotada]]
data[data["Weight (kg)"] > 60.4][["Gender","Weight (kg)"]][:4]
# Out:
#    Gender  Weight (kg)
# 0    Male         88.3
# 1  Female         74.9
# 2  Female         68.1
# 6    Male         70.3

# %%
data[(data["Weight (kg)"]<50)&(data["Height (m)"]>1.4)][["Gender","Weight (kg)","Height (m)",""]]
# Out:
#      Gender  Weight (kg)  Height (m)
# 4      Male         46.1        1.79
# 15   Female         42.5        1.75
# 17   Female         43.8        1.77
# 39     Male         45.5        1.60
# 40   Female         48.8        1.51
# ..      ...          ...         ...
# 883  Female         49.0        1.57
# 935  Female         45.2        1.68
# 940    Male         46.2        1.63
# 963  Female         43.8        1.75
# 965  Female         44.1        1.62
#
# [101 rows x 3 columns]

# %%
data[(data["Workout_Type"].str.contains("yoga",case=False))][["Workout_Type","Gender","Weight (kg)","Height (m)"]]
# Out:
#     Workout_Type  Gender  Weight (kg)  Height (m)
# 0           Yoga    Male         88.3        1.71
# 14          Yoga    Male        117.7        1.81
# 22          Yoga  Female         71.0        1.68
# 23          Yoga    Male        120.9        1.78
# 25          Yoga  Female         63.7        1.71
# ..           ...     ...          ...         ...
# 950         Yoga  Female         76.7        1.62
# 953         Yoga  Female         67.9        1.77
# 961         Yoga  Female         66.6        1.67
# 965         Yoga  Female         44.1        1.62
# 967         Yoga    Male         55.0        1.60
#
# [239 rows x 4 columns]

# %%
data.query('Workout_Type == "Yoga" and Max_BPM')[["Age","Gender","Max_BPM"]]
# Out:
#      Age  Gender  Max_BPM
# 22    50  Female      187
# 23    29    Male      197
# 25    42  Female      173
# 31    20  Female      185
# 42    43    Male      161
# ..   ...     ...      ...
# 905   54    Male      195
# 921   29  Female      175
# 932   31    Male      185
# 941   21    Male      161
# 953   50  Female      171
#
# [129 rows x 3 columns]

# %% [markdown]
# # Agregar y Quitar datos

# %%
import numpy as np
data["Peso"] = np.where(data["Weight (kg)"]==80)

data
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56    Male            0        1.71      180      157           60
# 1     46  Female            0        1.53      179      151           66
# 2     32  Female            0        1.66      167      122           54
# 3     25    Male            0        1.70      190      164           56
# 4      0       0            0        0.00        0        0            0
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male            0        1.74      187      158           67
# 969   25    Male            0        1.61      184      166           56
# 970   59  Female            0        1.76      194      120           53
# 971   32    Male            0        1.83      198      146           62
# 972   46    Male            0        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

data = pd.read_excel("GYM.xls")
#base[base[row especifica]filtro][[base acotada]]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\compat\_optional.py:142, in import_optional_dependency(name, extra, errors, min_version)
#     141 try:
# --> 142     module = importlib.import_module(name)
#     143 except ImportError:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1004, in _find_and_load_unlocked(name, import_)
#
# ...
